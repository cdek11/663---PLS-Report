# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale
from sklearn import cross_validation
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.cross_decomposition import PLSRegression, PLSSVD
from sklearn.metrics import mean_squared_error

# %%
ames_train = pd.read_csv("ames_train.csv")
ames_test = pd.read_csv("ames_test.csv")
ames_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 82 columns):
# Unnamed: 0         1500 non-null int64
# PID                1500 non-null int64
# area               1500 non-null int64
# price              1500 non-null int64
# MS.SubClass        1500 non-null int64
# MS.Zoning          1500 non-null object
# Lot.Frontage       1218 non-null float64
# Lot.Area           1500 non-null int64
# Street             1500 non-null object
# Alley              105 non-null object
# Lot.Shape          1500 non-null object
# Land.Contour       1500 non-null object
# Utilities          1500 non-null object
# Lot.Config         1500 non-null object
# Land.Slope         1500 non-null object
# Neighborhood       1500 non-null object
# Condition.1        1500 non-null object
# Condition.2        1500 non-null object
# Bldg.Type          1500 non-null object
# House.Style        1500 non-null object
# Overall.Qual       1500 non-null int64
# Overall.Cond       1500 non-null int64
# Year.Built         1500 non-null int64
# Year.Remod.Add     1500 non-null int64
# Roof.Style         1500 non-null object
# Roof.Matl          1500 non-null object
# Exterior.1st       1500 non-null object
# Exterior.2nd       1500 non-null object
# Mas.Vnr.Type       1494 non-null object
# Mas.Vnr.Area       1494 non-null float64
# Exter.Qual         1500 non-null object
# Exter.Cond         1500 non-null object
# Foundation         1500 non-null object
# Bsmt.Qual          1449 non-null object
# Bsmt.Cond          1449 non-null object
# Bsmt.Exposure      1448 non-null object
# BsmtFin.Type.1     1449 non-null object
# BsmtFin.SF.1       1500 non-null int64
# BsmtFin.Type.2     1449 non-null object
# BsmtFin.SF.2       1500 non-null int64
# Bsmt.Unf.SF        1500 non-null int64
# Total.Bsmt.SF      1500 non-null int64
# Heating            1500 non-null object
# Heating.QC         1500 non-null object
# Central.Air        1500 non-null object
# Electrical         1500 non-null object
# X1st.Flr.SF        1500 non-null int64
# X2nd.Flr.SF        1500 non-null int64
# Low.Qual.Fin.SF    1500 non-null int64
# Bsmt.Full.Bath     1499 non-null float64
# Bsmt.Half.Bath     1499 non-null float64
# Full.Bath          1500 non-null int64
# Half.Bath          1500 non-null int64
# Bedroom.AbvGr      1500 non-null int64
# Kitchen.AbvGr      1500 non-null int64
# Kitchen.Qual       1500 non-null object
# TotRms.AbvGrd      1500 non-null int64
# Functional         1500 non-null object
# Fireplaces         1500 non-null int64
# Fireplace.Qu       789 non-null object
# Garage.Type        1431 non-null object
# Garage.Yr.Blt      1430 non-null float64
# Garage.Finish      1430 non-null object
# Garage.Cars        1500 non-null int64
# Garage.Area        1500 non-null int64
# Garage.Qual        1430 non-null object
# Garage.Cond        1430 non-null object
# Paved.Drive        1500 non-null object
# Wood.Deck.SF       1500 non-null int64
# Open.Porch.SF      1500 non-null int64
# Enclosed.Porch     1500 non-null int64
# X3Ssn.Porch        1500 non-null int64
# Screen.Porch       1500 non-null int64
# Pool.Area          1500 non-null int64
# Pool.QC            7 non-null object
# Fence              317 non-null object
# Misc.Feature       53 non-null object
# Misc.Val           1500 non-null int64
# Mo.Sold            1500 non-null int64
# Yr.Sold            1500 non-null int64
# Sale.Type          1500 non-null object
# TotalSq            1500 non-null int64
# dtypes: float64(5), int64(35), object(42)
# memory usage: 961.0+ KB

# %%
y = ames_train.price
#x_predictors = pd.concat([ames_train.drop(["price", "PID"], axis=1)], axis = 1).astype("float64")
x_predictors = ames_train.drop(["price", "PID"], axis=1)
x_predictors.head(n=5)
# Out:
#    Unnamed: 0  area  MS.SubClass MS.Zoning  Lot.Frontage  Lot.Area Street  \
# 0           1  1654           70        RL          50.0      4960   Pave
# 1           2  2340           70        RL          66.0      9042   Pave
# 2           3  1466           20        RL         134.0     17755   Pave
# 3           4  1224          120        RM           NaN      4500   Pave
# 4           5  1575          120        RL          50.0      8012   Pave
#
#   Alley Lot.Shape Land.Contour   ...    Screen.Porch Pool.Area Pool.QC  Fence  \
# 0   NaN       Reg          Lvl   ...               0         0     NaN    NaN
# 1   NaN       Reg          Lvl   ...               0         0     NaN  GdPrv
# 2   NaN       Reg          Lvl   ...             100         0     NaN    NaN
# 3   NaN       Reg          Lvl   ...               0         0     NaN    NaN
# 4   NaN       Reg          Lvl   ...               0         0     NaN    NaN
#
#   Misc.Feature Misc.Val Mo.Sold Yr.Sold  Sale.Type  TotalSq
# 0          NaN        0       5    2009        WD      1654
# 1         Shed     2500       5    2010        WD      2340
# 2          NaN        0      11    2006        WD      1466
# 3          NaN        0       6    2009        WD      1224
# 4          NaN        0       7    2007        WD      1575
#
# [5 rows x 80 columns]

# %%
pca = PCA()
X_reduced = pca.fit_transform(scale(x_predictors))
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-32-6a0b6908a5d0> in <module>()
#       1 pca = PCA()
# ----> 2 X_reduced = pca.fit_transform(scale(x_predictors))
#
# /opt/conda/lib/python3.5/site-packages/sklearn/preprocessing/data.py in scale(X, axis, with_mean, with_std, copy)
#     127     X = check_array(X, accept_sparse='csc', copy=copy, ensure_2d=False,
#     128                     warn_on_dtype=True, estimator='the scale function',
# --> 129                     dtype=FLOAT_DTYPES)
#     130     if sparse.issparse(X):
#     131         if with_mean:
#
# /opt/conda/lib/python3.5/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     380                                       force_all_finite)
#     381     else:
# --> 382         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     383
#     384         if ensure_2d:
#
# ValueError: could not convert string to float: 'WD '

# %% [markdown]
# ### Description of algorithm
#
# PLS is a regression method used to overcome limitations discussed above for normal linear regressions (e.g., many collinear predictors, more predictors than samples, etc.) by mapping observed sets of observed variables to response variables by means of latent variables. Essentially the model assumes that the data is generated by an underlying model directed by a smaller number of latent variables in the data.
#
# First, two sets of latent variables are extracted from the data: $T$ (or x-scores) from the predictors, and $U$ (or y-scores) from the response variable. These latent vectors are determined through maximizing the covariance between different sets of variables.
#
# For the classic linear regression, we try to solve the equation, $ Y = XB + {\epsilon} $, where the ordinary least squares estimate for ${\beta}$ is identified as ${(X^T X)}^{-1} X^TY$. This estimate is obtained by minimizing the sum of squared residuals. However, models that have predictors with high collinearity or more predictors than observations can result in singularity of the matrix ${(X^T X)}$. As an alternative and way to fix this issue, we implement the PLS algorithm throught the following steps:
#
# 1) Start with vector $u$. If there is only one response variable, then $ u = y $, otherwise it is one of the columns of $Y$.
#
# 2) Calculate the weights for the predictors ($X$) :
# $$ w = \frac{X^Tu}{u^Tu} $$
#
# 3) Determine $t$ ($X$ scores):
# $$ t = Xw $$
#
# 4) Now perform similar calculations for $Y$. Calculate the weights for the response variable:
# $$ c = \frac{X^Tt}{t^Tt} $$
#
# 5) Determine $u$ ($Y$ scores):
# $$ u = \frac{Yc}{c^Tc} $$
#
# 6) If there is more than one response variable, then we test to determine whether the $t$ values have converged. If the change in $t$ from one iteration to the next, $ \frac{||t_{old} - t_{new}}{||t_{new}||} $, is not smaller than a threshold value, then we iterate through steps 2-5 until convergence is reached.
#
# 7) Deflate variables for next iteration.
# $$ p = \frac{X^Tt}{t^Tt} $$
# $$ X = X - tp^T $$
# $$ Y = Y - tc^T $$
#
# 8) Iterate through components until they are not found to be predictive of $Y$.
